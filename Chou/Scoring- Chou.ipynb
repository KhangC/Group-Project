# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#education = pd.read_excel('C:/Users/Khang/OneDrive/Desktop/Group Project 1/HGTV_Project.xlsx')
housing = pd.read_excel('C:/Users/Khang/OneDrive/Desktop/Group Project 1/plot_bar1.xlsx')
crime = pd.read_csv('C:/Users/Khang/OneDrive/Desktop/Group Project 1/Crime_10.csv')
housing
# Out:
#                 geo_name  Score
# 0           Modoc County     10
# 1            Kern County      9
# 2          Sutter County      8
# 3           Kings County      7
# 4        Imperial County      6
# 5          Tulare County      5
# 6          Merced County      4
# 7  San Bernardino County      3
# 8       Del Norte County      2
# 9           Butte County      1

# %%
crime
# Out:
#            geo_name  score
# 0     Placer County     10
# 1      Marin County      9
# 2    Ventura County      8
# 3   Tuolumne County      7
# 4     Colusa County      6
# 5    Trinity County      5
# 6     Orange County      4
# 7  San Mateo County      3
# 8  El Dorado County      2
# 9  Calaveras County      1

# %%
education = pd.read_excel('C:/Users/Khang/OneDrive/Desktop/Group Project 1/HGTV_Project.xlsx')
education
# Out:
#                  geo_name  Score
# 0        El Dorado County     10
# 1            Marin County      9
# 2           Nevada County      8
# 3           Placer County      7
# 4         Tuolumne County      6
# 5  San Luis Obispo County      5
# 6        San Mateo County      4
# 7            Butte County      3
# 8           Amador County      2
# 9        Calaveras County      1

# %%
new_df = pd.merge(crime, education, on='geo_name', how='outer')
new_df
# Out:
#                   geo_name  score  Score
# 0            Placer County   10.0    7.0
# 1             Marin County    9.0    9.0
# 2           Ventura County    8.0    NaN
# 3          Tuolumne County    7.0    6.0
# 4            Colusa County    6.0    NaN
# 5           Trinity County    5.0    NaN
# 6            Orange County    4.0    NaN
# 7         San Mateo County    3.0    4.0
# 8         El Dorado County    2.0   10.0
# 9         Calaveras County    1.0    1.0
# 10           Nevada County    NaN    8.0
# 11  San Luis Obispo County    NaN    5.0
# 12            Butte County    NaN    3.0
# 13           Amador County    NaN    2.0

# %%
new_df1 = pd.merge(new_df, housing, on='geo_name', how='outer')
new_df1
# Out:
#                   geo_name  score  Score_x  Score_y
# 0            Placer County   10.0      7.0      NaN
# 1             Marin County    9.0      9.0      NaN
# 2           Ventura County    8.0      NaN      NaN
# 3          Tuolumne County    7.0      6.0      NaN
# 4            Colusa County    6.0      NaN      NaN
# 5           Trinity County    5.0      NaN      NaN
# 6            Orange County    4.0      NaN      NaN
# 7         San Mateo County    3.0      4.0      NaN
# 8         El Dorado County    2.0     10.0      NaN
# 9         Calaveras County    1.0      1.0      NaN
# 10           Nevada County    NaN      8.0      NaN
# 11  San Luis Obispo County    NaN      5.0      NaN
# 12            Butte County    NaN      3.0      1.0
# 13           Amador County    NaN      2.0      NaN
# 14            Modoc County    NaN      NaN     10.0
# 15             Kern County    NaN      NaN      9.0
# 16           Sutter County    NaN      NaN      8.0
# ...

# %%
rename_df = new_df1.rename(columns={'score': 'score_crime', 'Score_x': 'score_education', 'Score_y': 'score_housing'})
rename_df
# Out:
#                   geo_name  score_crime  score_education  score_housing
# 0            Placer County         10.0              7.0            NaN
# 1             Marin County          9.0              9.0            NaN
# 2           Ventura County          8.0              NaN            NaN
# 3          Tuolumne County          7.0              6.0            NaN
# 4            Colusa County          6.0              NaN            NaN
# 5           Trinity County          5.0              NaN            NaN
# 6            Orange County          4.0              NaN            NaN
# 7         San Mateo County          3.0              4.0            NaN
# 8         El Dorado County          2.0             10.0            NaN
# 9         Calaveras County          1.0              1.0            NaN
# 10           Nevada County          NaN              8.0            NaN
# 11  San Luis Obispo County          NaN              5.0            NaN
# ...

# %%
rename_df['Final Score']= rename_df[['score_crime', 'score_education', 'score_housing']].sum(axis=1)
rename_df.sort_values(by=['Final Score'], inplace=True, ascending=False)
rename_df
# Out:
#                   geo_name  score_crime  score_education  score_housing  \
# 1             Marin County          9.0              9.0            NaN
# 0            Placer County         10.0              7.0            NaN
# 3          Tuolumne County          7.0              6.0            NaN
# 8         El Dorado County          2.0             10.0            NaN
# 14            Modoc County          NaN              NaN           10.0
# 15             Kern County          NaN              NaN            9.0
# 2           Ventura County          8.0              NaN            NaN
# 16           Sutter County          NaN              NaN            8.0
# 10           Nevada County          NaN              8.0            NaN
# 7         San Mateo County          3.0              4.0            NaN
# 17            Kings County          NaN              NaN            7.0
# 18         Imperial County          NaN              NaN            6.0
# ...

# %%
rename_df.to_excel("C:/Users/Khang/OneDrive/Desktop/Group Project 1/final_score.xlsx", header=True)
